# %% [markdown]
# # 머신러닝을 위한 numpy
# --------
# ### 넘파이를 왜 배워야하는가
#
# 넘파이를사용하는이유
#
# 넘파이의핵심 배열
#
# ### 넘파이의 배열의  구성요소와 생성
#
# 배열의 구성요소
#
# 배열의 자료형
#
# 배열의 모양
#
# 배열의 차원
#
# 배열의 축
#
# 배열생성하기
#
# ### 배열의 인덱싱
#
# 인덱싱
#
# boolean mask를 이용한 인덱싱
#
# 비교연산자를이용한 인덱싱
#
#  원소의인덱스를가져오는 메소드
#
# ### 배열의 결합과 변형
#
# 여러배열의 원소 합치기 np.concatenate
#
# 여러배열의 각원소로 새로운축 만들어 쌓기 np.stack
#
# 배열의 모양바꾸기 np.reshape
#
# 배열의 축바꾸기 np.transpose
#
# ### numpy의 다양한 함수 -원소단위
#
# 단일배열의 원소별 연산
#
# 같은크기를갖는배열간 원소 별연산
#
# 브로드케스팅 살펴보기
#
# 브로드캐스팅 성립규칙
#
# 브로드 캐스팅  VS For 순회문 비교하기
#
# 브로드캐스팅과 범용함수 활용하기
#
# ### 넘파이의 다양한 함수 -축단위
#
# 2차원에서의 축기준연산의 작동
#
# 3차원에서의 축기준연산의 작동
#
#  넘파이 array의 축기준 집계연산
#
#  배열의 원소간 기초통계랑 집계
#
# 배열의 다양한 집계
#
# 원소의 크기에 따라 정렬하기
